# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 5:</h2>|<h1>Observation (non-causal) mech interp<h1>|
# |<h2>Section:</h2>|<h1>Investigating token embeddings<h1>|
# |<h2>Lecture:</h2>|<h1><b>Parts of speech with SpaCy library<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
# https://spacy.io/
import spacy

nlp = spacy.load('en_core_web_sm')
txt = 'This is a very happy sentence that I will use to explore the spacy library.'

dir( nlp(txt) )

# %%
# split the text into words and print the part of speech (pos)
for word in txt.split():
  n = nlp(word)
  print(f'"{word}" is a {n[0].pos_}')

# %%
# more accurate to tokenize the sentence
for token in nlp(txt):
  print(f'"{token.text}" is a {token.pos_}')

# %% [markdown]
# # Part of speech from tokenized text

# %%
# import gpt2 tokenizer
from transformers import AutoModelForCausalLM, GPT2Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
# tokenize the text
tokens = tokenizer.encode(txt)

for t in tokens:
  toktxt = tokenizer.decode([t])
  print(f'Token "{toktxt}" is a {nlp(toktxt)[0].pos_}')

# %%
# try again...
for t in tokens:
  toktxt = tokenizer.decode([t]).strip()
  print(f'Token "{toktxt}" is a {nlp(toktxt)[0].pos_}')

# %% [markdown]
# # Try with text generated by GPT2

# %%
model = AutoModelForCausalLM.from_pretrained('gpt2')
model.eval();

# %%
# generate some text
newtoks = model.generate(tokenizer.encode('I think the world could be better if',return_tensors='pt'),max_length=400,do_sample=True)
print('\n\n',tokenizer.decode(newtoks[0]))

# %%
# initialize counters
isnoun = 0
isverb = 0

# loop over the tokens
for t in newtoks[0]:

  # get the text and part of speech
  txt = tokenizer.decode(t).replace(' ','') # instead of strip()
  pos = nlp(txt)[0].pos_

  # increment counters and print
  if pos=='NOUN':
    isnoun += 1
    print(f'{txt:>12} -> {pos}')
  elif pos=='VERB':
    print(f'{txt:>12} -> {pos}')
    isverb += 1

# %%
# check the counts
isnoun,isverb
