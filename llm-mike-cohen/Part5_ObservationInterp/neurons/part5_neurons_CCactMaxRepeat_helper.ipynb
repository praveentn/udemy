# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 5:</h2>|<h1>Observation (non-causal) mech interp<h1>|
# |<h2>Section:</h2>|<h1>Investigating neurons and dimensions<h1>|
# |<h2>Lecture:</h2>|<h1><b>CodeChallenge HELPER: Reproducibility of activation maximization<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn.functional as F
from transformers import GPT2Model, GPT2Tokenizer

# vector plots
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %% [markdown]
# # Exercise 1: A training function

# %%
# load GPT2 model and tokenizer
model = GPT2Model.from_pretrained('gpt2')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# store a copy of the original embeddings
embeddings =

# use GPU
device =

# move the model to the GPU

# %%
def trainingFunction():

  # initialize random embeddings and normalize the stds
  optimized_embeddings = torch.randn
  torch.nn.init.normal_(, mean=, std=)

  # create an optimizer
  optimizer = torch.optim.Adam([optimized_embeddings], lr=)


  # loop over training steps
  for step in range(n_steps):

    # clear gradient


    # patch embeddings directly into the model
    outputs = model(inputs_embeds =
    allActivations = outputs.h

    # extract the activations (averaged over tokens)
    neuron_activation = allActivations

    # calculate loss and run gradient descent
    loss = -neuron_activation + lambda_l2 *
    loss.backward()
    optimizer.step()

  # output the optimized embeddings
  return

# %%
# length of the token sequence
seq_len = 5

# dimension and layer to maximize
layer_idx =
dim_idx =

n_steps = 0   # optimization steps
lr =        # learning rate
lambda_l2 =  # regularization amount

# %%
### test it
optimized_embeddings = trainingFunction()

# %%
# decode embeddings to closest tokens
optimized_tokens = []

for emb in optimized_embeddings[0]:

  # cosine similarity with embedding weights
  similarities = F.cosine_similarity

  # find the max similarity
  maxtok =
  optimized_tokens.append

tokenizer.decode(optimized_tokens)

# %% [markdown]
# # Exercise 2: Run it 10x

# %%
# number of experiment repetitions
numberRepeats = 10

# initialize a matrix for all optimized tokens
all_optimized_tokens = np.zeros((),dtype=)


# start the loop!
for runi in

  # call the training function


  # decode embeddings to closest tokens
  optimized_tokens = []

  for embi,emb in enumerate

    # cosine similarity with embedding weights
    similarities = F.

    # find the max similarity
    maxtok =
    all_optimized_tokens[,] =

  # status
  print(f'Finished repeat {runi+1} of {numberRepeats}')

# %%
all_optimized_tokens

# %%
# get unique values and their counts
unitokens,counts =

print()

for t,c in zip(unitokens,counts):
  print(f'{} optimization for token "{}"')
