# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 3:</h2>|<h1>Evaluating LLMs<h1>|
# |<h2>Section:</h2>|<h1>Quantitative evaluations<h1>|
# |<h2>Lecture:</h2>|<h1><b>Import large models using bitsandbytes<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
import torch
from transformers import AutoModelForCausalLM

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# try to import the zephyr model...
zephyr_model = AutoModelForCausalLM.from_pretrained('HuggingFaceH4/zephyr-7b-alpha').to(device)

# %%
# run first to install and then restart
# !pip install bitsandbytes

# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

# need a BitsAndBytesConfig object
quantization_config = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_compute_dtype = 'float16', # multiplication at higher precision
    bnb_4bit_use_double_quant = True,   # help preserves accuracy
)

# import the model
zephyr_model = AutoModelForCausalLM.from_pretrained('HuggingFaceH4/zephyr-7b-alpha',
    quantization_config = quantization_config)

zephyr_model

# %%
# documentation about setting up the config object
# https://huggingface.co/docs/transformers/v4.27.1/en/main_classes/quantization#transformers.BitsAndBytesConfig

# %%
# documentation about this model:
# https://huggingface.co/HuggingFaceH4/zephyr-7b-alpha
